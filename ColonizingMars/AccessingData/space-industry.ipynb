# %% [markdown]
# ![Callysto.ca Banner](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-top.jpg?raw=true)
#
# <a href="https://hub.callysto.ca/jupyter/hub/user-redirect/git-pull?repo=https%3A%2F%2Fgithub.com%2Fcallysto%2Fhackathon&branch=master&subPath=ColonizingMars/AccessingData/earth-climate-data.ipynb&depth=1" target="_parent"><img src="https://raw.githubusercontent.com/callysto/curriculum-notebooks/master/open-in-callysto-button.svg?sanitize=true" width="123" height="24" alt="Open in Callysto"/></a>

# %% [markdown]
# # Space Industry
#
# The data has been downloaded from [data.world](https://data.world/l2sants/space-indrustry) and is now available at [Callysto Github repository](https://raw.githubusercontent.com/callysto/data-files/advance-fix/Science/Space-Industry/spaceCompanies.csv). This data allows you to look into information of 140 companies that are focused on space industry.

# %%
import pandas as pd
space_companies = pd.read_csv("spaceCompanies.csv").iloc[:,1:37]
space_companies.columns = space_companies.columns.str.lstrip("company/")
space_companies
# Out:
#                           _id  \
# 0    58caff7d6ed7bb3c6ee62d17
# 1    58d164516ed7bb3c6ee62e64
# 2    58d2bd156ed7bb3c6ee62ebd
# 3    58d2e3446ed7bb3c6ee62f05
# 4    58d37ead6ed7bb3c6ee62faa
# ..                        ...
# 149  5fc623237d4cc4392b19d7f6
# 150  5fff03f2975ca80e320d4442
# 151  600737546739ef1c3b04ea73
# 152  600836a59128e373747a163a
# 153  6011d1e36c2daf044dd2e53b
#
#                                                   bout  \
# 0    ATG Europe prides itself in employing Europe’s...
# 1    Telespazio VEGA UK is a dynamic and experience...
# 2    Tailored services for microsatellites.  Leaf s...
# 3    Oxford Space Systems is an award-winning space...
# 4    We are building a brighter future in which acc...
# ..                                                 ...
# 149                                                NaN
# 150                                                NaN
# 151  <p><b><span lang="EN-US" style="font-size: 10....
# ...

# %% [markdown]
# [![Callysto.ca License](https://github.com/callysto/curriculum-notebooks/blob/master/callysto-notebook-banner-bottom.jpg?raw=true)](https://github.com/callysto/curriculum-notebooks/blob/master/LICENSE.md)
