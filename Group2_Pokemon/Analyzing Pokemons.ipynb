# %%
import pandas as pd
from pylab import rcParams
import matplotlib 
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# ### Getting data and diplaying first 5 rows:

# %%
file_name="pokemon.csv"

# %%
#if reading from swift
import urllib
target_url="https://swift-yeg.cloud.cybera.ca:8080/v1/AUTH_d22d1e3f28be45209ba8f660295c84cf/hackaton/pokemon.csv"
urllib.request.urlretrieve(target_url, file_name)
# Out:
# ('pokemon.csv', <http.client.HTTPMessage at 0x7f34bf94dba8>)

# %%
pokemon = pd.read_csv(file_name) 
pokemon.head()
# Out:
#                      abilities  against_bug  against_dark  against_dragon  \
# 0  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 1  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 2  ['Overgrow', 'Chlorophyll']          1.0           1.0             1.0
# 3     ['Blaze', 'Solar Power']          0.5           1.0             1.0
# 4     ['Blaze', 'Solar Power']          0.5           1.0             1.0
#
#    against_electric  against_fairy  against_fight  against_fire  \
# 0               0.5            0.5            0.5           2.0
# 1               0.5            0.5            0.5           2.0
# 2               0.5            0.5            0.5           2.0
# 3               1.0            0.5            1.0           0.5
# 4               1.0            0.5            1.0           0.5
#
#    against_flying  against_ghost  ...  percentage_male  pokedex_number  \
# ...

# %%
pokemon.shape
# Out:
# (801, 41)

# %%
pokemon.columns
# Out:
# Index(['abilities', 'against_bug', 'against_dark', 'against_dragon',
#        'against_electric', 'against_fairy', 'against_fight', 'against_fire',
#        'against_flying', 'against_ghost', 'against_grass', 'against_ground',
#        'against_ice', 'against_normal', 'against_poison', 'against_psychic',
#        'against_rock', 'against_steel', 'against_water', 'attack',
#        'base_egg_steps', 'base_happiness', 'base_total', 'capture_rate',
#        'classfication', 'defense', 'experience_growth', 'height_m', 'hp',
#        'japanese_name', 'name', 'percentage_male', 'pokedex_number',
#        'sp_attack', 'sp_defense', 'speed', 'type1', 'type2', 'weight_kg',
#        'generation', 'is_legendary'],
#       dtype='object')

# %% [markdown]
# - **name**: The English name of the Pokemon
# - **japanese_name**: The Original Japanese name of the Pokemon
# - **pokedex_number**: The entry number of the Pokemon in the National Pokedex
# - **percentage_male**: The percentage of the species that are male. Blank if the Pokemon is genderless.
# - **type1**: The Primary Type of the Pokemon
# - **type2**: The Secondary Type of the Pokemon
# - **classfication**: The Classification of the Pokemon as described by the Sun and Moon Pokedex
# - **height_m**: Height of the Pokemon in metres
# - **weight_kg**: The Weight of the Pokemon in kilograms
# - **capture_rate**: Capture Rate of the Pokemon
# - **base_egg_steps**: The number of steps required to hatch an egg of the Pokemon
# - **abilities**: A stringified list of abilities that the Pokemon is capable of having
# - **experience_growth**: The Experience Growth of the Pokemon
# - **base_happiness**: Base Happiness of the Pokemon
# - **against_?**: Eighteen features that denote the amount of damage taken against an attack of a particular type
# - **hp**: The Base HP of the Pokemon
# - **attack**: The Base Attack of the Pokemon
# - **defense**: The Base Defense of the Pokemon
# - **sp_attack**: The Base Special Attack of the Pokemon
# - **sp_defense**: The Base Special Defense of the Pokemon
# - **speed**: The Base Speed of the Pokemon
# - **generation**: The numbered generation which the Pokemon was first introduced
# - **is_legendary**: Denotes if the Pokemon is legendary.

# %%
pokemon[["percentage_male","type1","type2","classfication","height_m","weight_kg","capture_rate",
         "base_egg_steps","abilities","experience_growth","base_happiness"]].head()
# Out:
#    percentage_male  type1   type2   classfication  height_m  weight_kg  \
# 0             88.1  grass  poison    Seed Pokémon       0.7        6.9
# 1             88.1  grass  poison    Seed Pokémon       1.0       13.0
# 2             88.1  grass  poison    Seed Pokémon       2.0      100.0
# 3             88.1   fire     NaN  Lizard Pokémon       0.6        8.5
# 4             88.1   fire     NaN   Flame Pokémon       1.1       19.0
#
#   capture_rate  base_egg_steps                    abilities  \
# 0           45            5120  ['Overgrow', 'Chlorophyll']
# 1           45            5120  ['Overgrow', 'Chlorophyll']
# 2           45            5120  ['Overgrow', 'Chlorophyll']
# 3           45            5120     ['Blaze', 'Solar Power']
# 4           45            5120     ['Blaze', 'Solar Power']
#
#    experience_growth  base_happiness
# 0            1059860              70
# 1            1059860              70
# 2            1059860              70
# ...

# %%
pokemon[["hp","attack","defense","sp_attack","speed","generation","is_legendary","name"]].head()
# Out:
#    hp  attack  defense  sp_attack  speed  generation  is_legendary        name
# 0  45      49       49         65     45           1             0   Bulbasaur
# 1  60      62       63         80     60           1             0     Ivysaur
# 2  80     100      123        122     80           1             0    Venusaur
# 3  39      52       43         60     65           1             0  Charmander
# 4  58      64       58         80     80           1             0  Charmeleon

# %% [markdown]
# ## Weight and hight
#
# ### What are the top 10 tallest pokemon and what is their weight?
# ###  What are the top 10 heaviest pokemon and what is their hihight?
# ### What are the top 10 lightests pokemon?

# %%
rcParams['figure.figsize'] = 15, 5
pokemon[["weight_kg","name"]].sort_values(by=['weight_kg'],ascending=False).head(10).set_index("name").plot(kind="bar")

# %%
pokemon[["weight_kg","height_m","name"]].sort_values(by=['weight_kg'],ascending=False).head(10)#.set_index("name").plot(kind="bar")
# Out:
#      weight_kg  height_m        name
# 789      999.9       0.1     Cosmoem
# 796      999.9       9.2  Celesteela
# 382      950.0       3.5     Groudon
# 749      920.0       2.5    Mudsdale
# 798      888.0       5.5    Guzzlord
# 486      750.0       4.5    Giratina
# 482      683.0       5.4      Dialga
# 375      550.0       1.6   Metagross
# 712      505.0       2.0     Avalugg
# 142      460.0       2.1     Snorlax

# %%
pokemon[["weight_kg","height_m","name"]].sort_values(by=['height_m'],ascending=False).head(10)#.set_index("name").plot(kind="bar")
# Out:
#      weight_kg  height_m        name
# 320      398.0      14.5     Wailord
# 207      400.0       9.2     Steelix
# 796      999.9       9.2  Celesteela
# 94       210.0       8.8        Onix
# 383      206.5       7.0    Rayquaza
# 129      235.0       6.5    Gyarados
# 349      162.0       6.2     Milotic
# 716      203.0       5.8     Yveltal
# 798      888.0       5.5    Guzzlord
# 482      683.0       5.4      Dialga

# %%
pokemon[["height_m","name"]].sort_values(by=['height_m']).head(10).set_index("name").plot(kind="bar")

# %% [markdown]
# ## Number of Pokemon by primary type
#
# ### How many  unique pokemon types (type1) exist?
# ### How many pokemons per type(type1)? pie chart
# ### Which types have the most(the least) number of pokemons?

# %%
pokemon["type1"].unique()
# Out:
# array(['grass', 'fire', 'water', 'bug', 'normal', 'poison', 'electric',
#        'ground', 'fairy', 'fighting', 'psychic', 'rock', 'ghost', 'ice',
#        'dragon', 'dark', 'steel', 'flying'], dtype=object)

# %%
len(pokemon["type1"].unique())
# Out:
# 18

# %%
pokemon["type1"].groupby(pokemon["type1"]).count().reset_index(name='count').sort_values(['count'], ascending=False)
# Out:
#        type1  count
# 17     water    114
# 12    normal    105
# 9      grass     78
# 0        bug     72
# 14   psychic     53
# 6       fire     52
# 15      rock     45
# 3   electric     39
# 10    ground     32
# 13    poison     32
# 1       dark     29
# 5   fighting     28
# 8      ghost     27
# 2     dragon     27
# 16     steel     24
# 11       ice     23
# 4      fairy     18
# 7     flying      3

# %%
rcParams['figure.figsize'] = 15, 15
pokemon["type1"].groupby(pokemon["type1"]).count().plot(kind="pie")

# %% [markdown]
# ### What are the secondary types(type2) for water pokemon?

# %%
pokemon[pokemon["type1"]=="water"]["type2"].unique()
# Out:
# array([nan, 'fighting', 'poison', 'psychic', 'ice', 'flying', 'electric',
#        'fairy', 'ground', 'rock', 'dragon', 'grass', 'dark', 'steel',
#        'ghost', 'bug'], dtype=object)

# %%
pokemon[pokemon["type1"]=="water"]["type2"].groupby(pokemon["type2"]).count()#.reset_index(name='count').sort_values(['count'], ascending=False)
# Out:
# type2
# bug         2
# dark        4
# dragon      2
# electric    2
# fairy       4
# fighting    2
# flying      7
# ghost       2
# grass       3
# ground      9
# ice         3
# poison      3
# psychic     5
# rock        4
# steel       1
# Name: type2, dtype: int64

# %% [markdown]
# ### How many water pokemon does not have secondary type?

# %%
pokemon[pokemon["type1"]=="water"]["type2"].isna().sum()
# Out:
# 61

# %% [markdown]
# ## Attack and defense
#
# ### What are the top 20 pokemon with largest basic attack? And what is their defense?
# ### What are the top 20 pokemon with largest basic defense? And what is their attack?
#
# ### What are the top 10 pokemon with largest special attack? What are their attack, special defense and defense?

# %%
rcParams['figure.figsize'] = 15, 5
pokemon[["attack","defense","name"]].sort_values(by=['attack','defense'], ascending=False).head(20).set_index("name").plot.bar()

# %%
#rcParams['figure.figsize'] = 15, 10
pokemon[["attack","defense","name"]].sort_values(by=['defense','attack'], ascending=False).head(20).set_index("name").plot.bar()#(x="defense", y="attack",s=df['c'] * 200)

# %%
pokemon[["sp_attack","attack","sp_defense","defense","name"]].sort_values(by=['sp_attack','attack','sp_defense','defense'], ascending=False).head(10).set_index("name").plot.bar()

# %% [markdown]
# ## Attack and defense by primary type
#
# ### Find the best pokemon (having the largest basic attack) in every primary type (type1)
# ### Plot the top 10 types having the strongest pokemon (type + pokemon name)
# ### Do the same for defense
# ### Bonus: plot the attacka nd ddefense for every pokemon and color by primary type

# %%
rcParams['figure.figsize'] = 15, 10
pokemon["name_type1"]=pokemon["type1"]+": "+pokemon["name"]
pokemon[["type1","attack","name_type1"]].groupby(pokemon["type1"]).max().set_index("name_type1").sort_values(by=['attack'], ascending=False).plot(kind="barh")

# %%
pokemon[["type1","name_type1","defense"]].groupby(pokemon["type1"]).max().set_index("name_type1").sort_values(by=['defense'], ascending=False).plot(kind="bar")

# %%
groups = pokemon[["attack","defense","name","type1"]].groupby('type1')
rcParams['figure.figsize'] = 10, 10
# Plot
fig, ax = plt.subplots()
ax.margins(0.05) # Optional, just adds 5% padding to the autoscaling
for name, group in groups:
    ax.plot(group.attack, group.defense, marker='o', linestyle='', ms=8, label=name)
ax.legend()
plt.xlabel('basic attack')
plt.ylabel('basic defense')
plt.show()

# %% [markdown]
# ### Legendary pokemon
#
# ### How many legenday pokemons are there? Print them

# %%
pokemon[pokemon["is_legendary"]==1]["name"]
# Out:
# 143      Articuno
# 144        Zapdos
# 145       Moltres
# 149        Mewtwo
# 150           Mew
# 242        Raikou
# 243         Entei
# 244       Suicune
# 248         Lugia
# 249         Ho-Oh
# 250        Celebi
# 376      Regirock
# 377        Regice
# 378     Registeel
# 379        Latias
# 380        Latios
# 381        Kyogre
# 382       Groudon
# 383      Rayquaza
# 384       Jirachi
# 385        Deoxys
# 479          Uxie
# 480       Mesprit
# 481         Azelf
# 482        Dialga
# 483        Palkia
# 484       Heatran
# 485     Regigigas
# 486      Giratina
# 487     Cresselia
#           ...
# 642      Reshiram
# 643        Zekrom
# 644      Landorus
# 645        Kyurem
# 646        Keldeo
# 647      Meloetta
# 648      Genesect
# 715       Xerneas
# 716       Yveltal
# 717       Zygarde
# 718       Diancie
# 719         Hoopa
# 720     Volcanion
# 784     Tapu Koko
# 785     Tapu Lele
# 786     Tapu Bulu
# 787     Tapu Fini
# 788        Cosmog
# 789       Cosmoem
# ...

# %% [markdown]
# ## The number of steps required to hatch an egg of the Pokemon
#
# ### Create a pie chart based on number of steps
# ### Which pokemons are the quickes to hatch

# %%
rcParams['figure.figsize'] = 5, 5
pokemon["base_egg_steps"].groupby(pokemon["base_egg_steps"]).count().plot(kind="pie")

# %%
pokemon["base_egg_steps"].groupby(pokemon["base_egg_steps"]).count().reset_index(name='count').sort_values(['count'])
# Out:
#    base_egg_steps  count
# 0            1280      2
# 6            8960     13
# 8           20480     16
# 1            2560     22
# 5            7680     26
# 7           10240     42
# 9           30720     49
# 4            6400     55
# 2            3840    140
# 3            5120    436

# %%
pokemon[pokemon["base_egg_steps"]==1280]["name"]
# Out:
# 128    Magikarp
# 129    Gyarados
# Name: name, dtype: object
